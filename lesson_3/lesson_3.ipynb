# %% [markdown]
# # Урок 3

# %%
import numpy as np
import math

# %%
# Формула числа размещений
def combi(n, k):
    return int(math.factorial(n) / (math.factorial(k) * math.factorial(n - k)))

# %% [markdown]
# ### 1.
# Даны значения зарплат из выборки выпускников: 100, 80, 75, 77, 89, 33, 45, 25, 65, 17, 30, 24, 57, 55, 70, 75, 65, 84, 90, 150. Посчитать (желательно без использования статистических методов наподобие std, var, mean) среднее арифметическое, среднее квадратичное отклонение, смещенную и несмещенную оценки дисперсий для данной выборки.

# %% [markdown]
# ### Решение.

# %%
salary = np.array([100, 80, 75, 77, 89, 33, 45, 25, 65, 17, 30, 24, 57, 55, 70, 75, 65, 84, 90, 150])
n = len(salary)
mean = sum(salary) / n
var = sum((salary - mean)**2) / n
var1 = sum((salary - mean)**2) / (n - 1)
std = var1**0.5 #Среднее квадратичное отклонение на основании несмещённой оценки дисперсии

print('Среднее арифметическое:', mean)
print('Среднее квадратичное отклонение:', std)
print('Смещенная оценка дисперсии:', var)
print('Несмещенная оценка дисперсии:', var1)

print('\nПроверка:')
print('Среднее арифметическое:', salary.mean())
print('Среднее квадратичное отклонение:', salary.std(ddof=1))
print('Смещенная оценка дисперсии:', salary.var())
print('Несмещенная оценка дисперсии:', salary.var(ddof=1))
# Out:
# Среднее арифметическое: 65.3
# Среднее квадратичное отклонение: 31.624607341019814
# Смещенная оценка дисперсии: 950.11
# Несмещенная оценка дисперсии: 1000.1157894736842
#
# Проверка:
# Среднее арифметическое: 65.3
# Среднее квадратичное отклонение: 31.624607341019814
# Смещенная оценка дисперсии: 950.11
# Несмещенная оценка дисперсии: 1000.1157894736842

# %% [markdown]
# ### 2.
# В первом ящике находится 8 мячей, из которых 5 - белые. Во втором ящике - 12 мячей, из которых 5 белых. Из первого ящика вытаскивают случайным образом два мяча, из второго - 4. Какова вероятность того, что 3 мяча белые?

# %% [markdown]
# ### Решение.

# %% [markdown]
# Вероятность складывается из суммы вероятностей:<br>
# 1) в первом ящике 2 мяча белых во втором 1 мяч белый;<br>
# 2) в первом ящике 1 мяч белый во втором 2 мяча белых;<br>
# 3) в первом ящике 0 мячей белых во втором 3 мяча белых.

# %%
combi(5, 2) / combi(8, 2) * combi(5, 1) * combi(12 - 5, 3) / combi(12, 4) + \
combi(5, 1) * combi(8 - 5, 1) / combi(8, 2) * combi(5, 2) * combi(12 - 5, 2) / combi(12, 4) + \
combi(8 - 5, 2) / combi(8, 2) * combi(5, 3) * combi(12 - 5, 1) / combi(12, 4)
# Out:
# 0.3686868686868686

# %% [markdown]
# ### 3.
# На соревновании по биатлону один из трех спортсменов стреляет и попадает в мишень. Вероятность попадания для первого спортсмена равна 0.9, для второго — 0.8, для третьего — 0.6. Найти вероятность того, что выстрел произведен: a). первым спортсменом б). вторым спортсменом в). третьим спортсменом.

# %% [markdown]
# ### Решение.

# %% [markdown]
# Воспользуемся формулой Баейса

# %%
Pb1 = 1/3
Pb2 = 1/3
Pb3 = 1/3
Pab1 = 0.9
Pab2 = 0.8
Pab3 = 0.6
Pa = Pab1 * Pb1 + Pab2 * Pb2 + Pab3 * Pb3
print('Вероятность для спортсмена 1:', Pb1 * Pab1 / Pa)
print('Вероятность для спортсмена 2:', Pb2 * Pab2 / Pa)
print('Вероятность для спортсмена 3:', Pb3 * Pab3 / Pa)
# Out:
# Вероятность для спортсмена 1: 0.391304347826087
# Вероятность для спортсмена 2: 0.3478260869565218
# Вероятность для спортсмена 3: 0.2608695652173913

# %% [markdown]
# ### 4.
# В университет на факультеты A и B поступило равное количество студентов, а на факультет C студентов поступило столько же, сколько на A и B вместе. Вероятность того, что студент факультета A сдаст первую сессию, равна 0.8. Для студента факультета B эта вероятность равна 0.7, а для студента факультета C - 0.9. Студент сдал первую сессию. Какова вероятность, что он учится: a). на факультете A б). на факультете B в). на факультете C?

# %% [markdown]
# ### Решение.

# %% [markdown]
# Воспользуемся формулой Баейса

# %%
Pb1 = 1/4
Pb2 = 1/4
Pb3 = 1/2
Pab1 = 0.8
Pab2 = 0.7
Pab3 = 0.9
Pa = Pab1 * Pb1 + Pab2 * Pb2 + Pab3 * Pb3
print('Вероятность на факультете A:', Pb1 * Pab1 / Pa)
print('Вероятность на факультете B:', Pb2 * Pab2 / Pa)
print('Вероятность на факультете C:', Pb3 * Pab3 / Pa)
# Out:
# Вероятность на факультете A: 0.24242424242424246
# Вероятность на факультете B: 0.21212121212121213
# Вероятность на факультете C: 0.5454545454545455

# %% [markdown]
# ### 5.
# Устройство состоит из трех деталей. Для первой детали вероятность выйти из строя в первый месяц равна 0.1, для второй - 0.2, для третьей - 0.25. Какова вероятность того, что в первый месяц выйдут из строя: а). все детали б). только две детали в). хотя бы одна деталь г). от одной до двух деталей?

# %% [markdown]
# ### Решение.

# %%
p1 = 0.1
p2 = 0.2
p3 = 0.25

print('Все детали:', p1 * p2 * p3)
# Для "только две детали" вероятность будет равна сумме вероятностей выхода из строя деталей 1+2, 1+3, 2+3
print('Только две детали:', p1 * p2 * (1 - p3) + p1 * p3 * (1 - p2) + p2 * p3 * (1 - p1))
# Для "хотя бы одна деталь" проще будет из общей вероятности вычесть вероятность что ничего не выйдет из строя
print('Хотя бы одна деталь:', 1 - (1 - p1) * (1 - p2) * (1 - p3))
# Для "от одной до двух деталей" проще будет из общей вероятности вычесть вероятность что ничего не выйдет 
# из строя и вычесть вероятность выхода из строя всех 3-х деталей
print('От одной до двух деталей:', 1 - (1 - p1) * (1 - p2) * (1 - p3) - p1 * p2 * p3)
# Out:
# Все детали: 0.005000000000000001
# Только две детали: 0.08000000000000002
# Хотя бы одна деталь: 0.45999999999999996
# От одной до двух деталей: 0.45499999999999996
